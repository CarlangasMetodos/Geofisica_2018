# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#PARTE A Circuito en Serie

L=np.linspace(0,1,100)
def funcion(L):
    rho=L+1000*(1-L)
    log=np.log(rho)
    return log

#PARTE B Circuito en Paralelo
def funcion2(L):
    rho=1000/(1000*L+1-L)
    log=np.log(rho)
    return log

#PARTE C Para resistividad usando Archie, con Pw=1, phi entre 0 y 1, m=1 y m=2

phi=L
def funcion3(phi,m):
    rho=phi**-m
    log=np.log(rho)
    return log

plt.plot(L,funcion(L), label='Serie')
plt.plot(L,funcion2(L), label='Paralelo')
plt.plot(L,funcion3(phi,2),label='Archie, m=2')
plt.plot(L,funcion3(phi,1),label='Arche,m=1')
plt.ylabel('Resistividad')
plt.xlabel('Longitud')
plt.legend()
plt.show()
# Out:
# /srv/conda/lib/python3.6/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in power
# /srv/conda/lib/python3.6/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in reciprocal
